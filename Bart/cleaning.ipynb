# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
all_data = pd.read_csv("clean_data.csv", delimiter=',')
# data = all_data.loc[all_data['Q1'] == 'Ja']
# data = data.loc[data['Q4'] != 'Nee']
# cols_to_drop = list(data.columns[:9]) + list(data.columns[40:159]) + list(data.columns[-2:])
# data = data.drop(cols_to_drop, axis=1)
col_drop = 
# all_data
all_data
# Out:
# ['Q12F_alt', 'Q13G_alt', 'Q16G_alt', 'Q45X_alt']

# %%
# data = data.reset_index(drop=True)
# data = data.replace(" ", np.nan)
# nan = [index for index, row in data.iterrows() if row.isnull().sum() > 70]

# data = data.drop(data.index[nan])
# data = data.drop(['index'], axis=1)
# data

# %%
import regex as re
# N = 2287
data = data.replace(" ", np.nan)
data['full_count'] = data.apply(lambda x: x.count(), axis=1)

unfilled_Qs = len(data) - data.count()
drop_alts = [x for x in data.columns if re.match(r'Q\d\d[^A]', x)]
data = data.drop(drop_alts, axis=1)
not_answered_N = len(data) - data.count()
# print(data)
# data
plt.bar(data.columns,not_answered_N/N*100)
plt.xticks(rotation=45)
plt.show()
# print(not_answered_N)
sum(data['Q11'] == 'Ik wil niet vaker en/of meer kilometers hardlopen dan ik nu doe')
sum(data['Q12A'].isnull()) - sum(data['Q11'] == 'Ik wil niet vaker en/of meer kilometers hardlopen dan ik nu doe')
# Out:
# 142

# %%
# for cell in data['Q50']:
#     if type(cell) is str:
# #         print(cell)
#         if len(cell) > 3:
#             float(cell.replace(',', '.'))
            
# data = data.loc[data['Q50'] > 3]
# Out:
#   File "<ipython-input-124-1e72cd838ace>", line 8
#     data['Q50'].apply(lambda x: x.replace(',','.') if x is str)
#                                                               ^
# SyntaxError: invalid syntax

# %%
data
# Out:
#                                                      Q8  \
# 1     Geen aparte trainingsperiode (ik train geduren...
# 2     Geen aparte trainingsperiode (ik train geduren...
# 3                           Niet of nauwelijks getraind
# 4     Geen aparte trainingsperiode (ik train geduren...
# 5                                                   NaN
# 8     Geen aparte trainingsperiode (ik train geduren...
# 9                                                   NaN
# 17                                                  NaN
# 19    Geen aparte trainingsperiode (ik train geduren...
# 21                            12 weken of meer getraind
# 22                          Niet of nauwelijks getraind
# 24                                  6-11 weken getraind
# 25                          Niet of nauwelijks getraind
# 26    Geen aparte trainingsperiode (ik train geduren...
# 27    Geen aparte trainingsperiode (ik train geduren...
# 28    Geen aparte trainingsperiode (ik train geduren...
# ...
